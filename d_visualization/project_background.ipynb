# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
stat = pd.read_csv("./datasets/year_age_stats.csv")
stat.head()
# Out:
#    Year    Total  Age_0_20  Age_21_30  Age_31_40  Age_41_50  Age_51_60  \
# 0  1992  2353888    165303     506799     655888     437041     347713
# 1  1993  2742722    187117     584081     771697     529995     403083
# 2  1994  3478199    238102     741700     969774     685434     520589
# 3  1995  4155787    297653     892286    1142483     826261     620483
# 4  1996  4960735    398273    1104160    1300282     993990     720287
#
#    Age_61_over  Crew
# 0       241144   NaN
# 1       266749   NaN
# 2       322600   NaN
# 3       376621   NaN
# 4       443743   NaN

# %%
stat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         30 non-null     int64
#  1   Total        30 non-null     int64
#  2   Age_0_20     30 non-null     int64
#  3   Age_21_30    30 non-null     int64
#  4   Age_31_40    30 non-null     int64
#  5   Age_41_50    30 non-null     int64
#  6   Age_51_60    30 non-null     int64
#  7   Age_61_over  30 non-null     int64
#  8   Crew         24 non-null     float64
# dtypes: float64(1), int64(8)
# memory usage: 2.2 KB

# %%
stat = stat[["Year","Total"]]

# %%
data = {"Year": ["2022","2023","2024"],
       "Total": [6554031 ,22715841 ,28686435 ]}


data  = pd.DataFrame(data)
data
# Out:
#    Year     Total
# 0  2022   6554031
# 1  2023  22715841
# 2  2024  28686435

# %%
stat = pd.concat([stat, pd.DataFrame(data)], ignore_index=True)

# %%
# 전체 평균도 시각화 해주기 위해서 대륙 리스트에 mean 추가
years = stat.Year.tolist() # 인덱스 리스트 넘기기

x_pos = np.arange(len(years))
hp = stat.Total.tolist() # con_mean을 리스트화

bar_list = plt.bar(x_pos,hp,alpha = 0.5)

# 마지막 바 만 빨간색으로 변경
bar_list[-1].set_color("r") # .set(color= "r") 이것도 가능

# 아래와 같은 방법도 있음
# plt.hlines(alc_mean,0,6,color="black",linestyle="solid") 
plt.xticks(x_pos,years,rotation=90)
plt.title("happiness_score")
plt.show()
